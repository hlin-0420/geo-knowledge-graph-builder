# %%
from bs4 import BeautifulSoup
import pandas as pd
from pathlib import Path

# %%
# Get the current working directory (might be different in Jupyter)
current_dir = Path.cwd()

table_types_filepath = (current_dir / '..' / '..' / '..' / 'Data' / 'Working_with_Files' / 'File_Types_Handled_by_GEO.htm').resolve()

# %%
def extract_geo_file_types(htm_file_path):
    """
    Extracts the file type information from GEO HTM file.
    
    Args:
        htm_file_path (str): Path to the HTM file
        
    Returns:
        pandas.DataFrame: DataFrame containing the extracted table data
    """
    # Read the HTM file
    with open(htm_file_path, 'r', encoding='utf-8') as file:
        html_content = file.read()
    
    # Parse the HTML using BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')
    
    # Find the main table (it has class "Table_Style_1")
    table = soup.find('table', {'class': 'Table_Style_1'})
    
    # Extract table headers
    headers = []
    header_row = table.find('tr')
    for th in header_row.find_all('td'):
        headers.append(th.get_text(strip=True))
    
    # Extract table rows
    data = []
    for row in table.find_all('tr')[1:]:  # Skip header row
        row_data = []
        for td in row.find_all('td'):
            # Clean up the text - remove extra spaces and newlines
            text = td.get_text(' ', strip=True)
            row_data.append(text)
        data.append(row_data)
    
    # Create a DataFrame
    df = pd.DataFrame(data, columns=headers)
    
    return df

# %%
table_types_df = extract_geo_file_types(table_types_filepath)

# %%
table_types_df
# Out:
#                           FILE TYPE            EXTENSION  \
# 0                            LIS-79   LIS, TAP, NTI, TIF
# 1   Canadian Well Log ASCII (CWLAS)         LASData_load
# 2                      Text (ASCII)    ASC, TXTData_load
# 3    Comma Separated Values (ASCII)         CSVData_load
# 4             Tab Delimited (ASCII)         TXTData_load
# 5                          Metafile        CGMExport_CGM
# 6                  Windows Metafile        WMFExport_WMF
# 7                 Enhanced Metafile        EMFExport_EMF
# 8          Scalable Vector Graphics        SVGExport_SVG
# 9       Extensible Mark-up Language        XMLExport_XML
# 10                             VIEW                  VEW
# 11             Output Database File                  ODF
# 12            ODF Database Template                  ODT
# 13                ODF Interval File                  OIF
# 14                  ODF Update File  OUFFiles_OUFConcept
# 15    GEODraft Output Database File                  GDF
# 16               GEODraft View File                  GDV
# 17           GEOGraph Database file                  GGD
# 18           GEOGraph Template file                  GGT
#
#                                           DESCRIPTION LOAD EXPORT
# 0   LIS data (usually wireline data) is converted ...   No     No
# 1   This is a special ASCII implementation of wire...  Yes    Yes
# 2   Mudlog, MWD and well test data are usually in ...  Yes    Yes
# 3   Some service companies present mudlog data as ...  Yes    Yes
# 4   One form of ASCII formats. Tab delimited files...  Yes    Yes
# 5   The ISO-8632 implementation of Computer Graphi...   No    Yes
# 6   Both placeable and standard Windows Metafiles ...   No    Yes
# 7   Enhanced Metafiles are supported. This is anot...  Yes    Yes
# 8   SVG is a language for describing two-dimension...         Yes
# 9   The Extensible Markup Language (XML) is the un...   No     No
# 10  The View file contains the layout-related sett...  Yes    Yes
# 11  The Output Database File is a database where t...   No     No
# 12  File that is created from an ODF with all requ...   No     No
# 13  These files are concerned with only a specific...  Yes    Yes
# 14  Small and sequential update files, which only ...  Yes    Yes
# 15  This is a file format equivalent to the ODF, b...   No    Yes
# 16  This is a file format equivalent to the VEW, b...  Yes    Yes
# 17  This is the file type created by the GEOGraph ...  Yes    Yes
# 18  This is the template version of the GGD file. ...  Yes     No
